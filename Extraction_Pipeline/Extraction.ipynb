# %%
import pandas as pd
import re

# Load data from CSV file
file_path = 'C:/Users/Bhargav/TravelAgentChatBot/chat-agent/scrapped.csv' 
df = pd.read_csv(file_path, header=None, names=['Raw Data'])

# Function to extract features with detailed debugging
def extract_features(row):
    # Regex patterns
    pattern_general = r'Restaurant (?P<name>.+) proche (?P<location>.+) - Restaurant - (?P=location) - (?P<cuisine>.+)'
    pattern_specific = r'(?P<name>.+) - (?P<address>.+), (?P<postal_code>\d{5}), (?P<city>[^-]+) - (?P<cuisine>.+)'

    # Debug: print the current row being processed
    print("Processing row:", row['Raw Data'])
    
    # Match general pattern
    match_general = re.match(pattern_general, row['Raw Data'])
    if match_general:
        print("General match found:", match_general.groupdict())  # Debug: print matched groups
        return {
            'Name': match_general.group('name'),
            'Address': None,
            'Postal Code': None,
            'City': match_general.group('location').split(' ')[-1],
            'District': match_general.group('location').split()[-1],
            'Cuisine Type': match_general.group('cuisine')
        }
    
    # Match specific pattern
    match_specific = re.match(pattern_specific, row['Raw Data'])
    if match_specific:
        print("Specific match found:", match_specific.groupdict())  # Debug: print matched groups
        return {
            'Name': match_specific.group('name'),
            'Address': match_specific.group('address'),
            'Postal Code': match_specific.group('postal_code'),
            'City': match_specific.group('city').strip(),
            'District': match_specific.group('postal_code')[-2:],
            'Cuisine Type': match_specific.group('cuisine')
        }
    
    # If neither pattern matches, print a debug message
    print("No match found for this row.")
    return {
        'Name': None,
        'Address': None,
        'Postal Code': None,
        'City': None,
        'District': None,
        'Cuisine Type': None
    }

# Apply feature extraction
features = df.apply(extract_features, axis=1, result_type='expand')

# Print the first few rows of extracted features to debug
print("Extracted Features DataFrame:")
print(features.head())

# Concatenate features to the original DataFrame
df = pd.concat([df, features], axis=1)

# Drop the raw data column
df.drop(columns=['Raw Data'], inplace=True)

# Save to CSV
output_csv_path = 'C:/Users/Bhargav/TravelAgentChatBot/extracted_features.csv'
df.to_csv(output_csv_path, index=False)

print(f"Processed data saved to {output_csv_path}")
print(df.head())  # Display the first few rows of the DataFrame
# Out:
# Processing row: Restaurant Poulet proche Paris 13ème - Restaurant - Paris 13ème - Poulet
# General match found: {'name': 'Poulet', 'location': 'Paris 13ème', 'cuisine': 'Poulet'}
# Processing row: Restaurant Pizza proche Paris 13ème - Restaurant - Paris 13ème - Pizza
# General match found: {'name': 'Pizza', 'location': 'Paris 13ème', 'cuisine': 'Pizza'}
# Processing row: Restaurant Pad Thai proche Paris 13ème - Restaurant - Paris 13ème - Pad Thai
# General match found: {'name': 'Pad Thai', 'location': 'Paris 13ème', 'cuisine': 'Pad Thai'}
# Processing row: Restaurant Sushi proche Paris 13ème - Restaurant - Paris 13ème - Sushi
# General match found: {'name': 'Sushi', 'location': 'Paris 13ème', 'cuisine': 'Sushi'}
# Processing row: Restaurant Couscous proche Paris 13ème - Restaurant - Paris 13ème - Couscous
# General match found: {'name': 'Couscous', 'location': 'Paris 13ème', 'cuisine': 'Couscous'}
# Processing row: Restaurant Pâtes proche Paris 13ème - Restaurant - Paris 13ème - Pâtes
# General match found: {'name': 'Pâtes', 'location': 'Paris 13ème', 'cuisine': 'Pâtes'}
# Processing row: Restaurant Burger proche Paris 13ème - Restaurant - Paris 13ème - Burger
# General match found: {'name': 'Burger', 'location': 'Paris 13ème', 'cuisine': 'Burger'}
# Processing row: Restaurant Truffe proche Paris 13ème - Restaurant - Paris 13ème - Truffe
# General match found: {'name': 'Truffe', 'location': 'Paris 13ème', 'cuisine': 'Truffe'}
# Processing row: Restaurant Bobun proche Paris 13ème - Restaurant - Paris 13ème - Bobun
# General match found: {'name': 'Bobun', 'location': 'Paris 13ème', 'cuisine': 'Bobun'}
# Processing row: Restaurant Tandoori proche Paris 13ème - Restaurant - Paris 13ème - Tandoori
# General match found: {'name': 'Tandoori', 'location': 'Paris 13ème', 'cuisine': 'Tandoori'}
# Processing row: Restaurant Falafel proche Paris 13ème - Restaurant - Paris 13ème - Falafel
# General match found: {'name': 'Falafel', 'location': 'Paris 13ème', 'cuisine': 'Falafel'}
# Processing row: Restaurant Viande et grillades proche Paris 13ème - Restaurant - Paris 13ème - Viande et grillades
# General match found: {'name': 'Viande et grillades', 'location': 'Paris 13ème', 'cuisine': 'Viande et grillades'}
# Processing row: Restaurant Escargots proche Paris 13ème - Restaurant - Paris 13ème - Escargots
# General match found: {'name': 'Escargots', 'location': 'Paris 13ème', 'cuisine': 'Escargots'}
# Processing row: Restaurant Wok proche Paris 13ème - Restaurant - Paris 13ème - Wok
# General match found: {'name': 'Wok', 'location': 'Paris 13ème', 'cuisine': 'Wok'}
# Processing row: Restaurant Poke Bowl proche Paris 13ème - Restaurant - Paris 13ème - Poke Bowl
# General match found: {'name': 'Poke Bowl', 'location': 'Paris 13ème', 'cuisine': 'Poke Bowl'}
# Processing row: Restaurant Foie Gras proche Paris 13ème - Restaurant - Paris 13ème - Foie Gras
# General match found: {'name': 'Foie Gras', 'location': 'Paris 13ème', 'cuisine': 'Foie Gras'}
# Processing row: Restaurant Options végétariennes proche Paris 13ème - Restaurant - Paris 13ème - Options végétariennes
# General match found: {'name': 'Options végétariennes', 'location': 'Paris 13ème', 'cuisine': 'Options végétariennes'}
# Processing row: Restaurant Options vegan proche Paris 13ème - Restaurant - Paris 13ème - Options vegan
# General match found: {'name': 'Options vegan', 'location': 'Paris 13ème', 'cuisine': 'Options vegan'}
# Processing row: Restaurant Options sans gluten proche Paris 13ème - Restaurant - Paris 13ème - Options sans gluten
# General match found: {'name': 'Options sans gluten', 'location': 'Paris 13ème', 'cuisine': 'Options sans gluten'}
# Processing row: Restaurant Produits locaux proche Paris 13ème - Restaurant - Paris 13ème - Produits locaux
# General match found: {'name': 'Produits locaux', 'location': 'Paris 13ème', 'cuisine': 'Produits locaux'}
# Processing row: Restaurant Plats bio proche Paris 13ème - Restaurant - Paris 13ème - Plats bio
# General match found: {'name': 'Plats bio', 'location': 'Paris 13ème', 'cuisine': 'Plats bio'}
# Processing row: Restaurant Halal proche Paris 13ème - Restaurant - Paris 13ème - Halal
# General match found: {'name': 'Halal', 'location': 'Paris 13ème', 'cuisine': 'Halal'}
# Processing row: Restaurant Les mieux notés proche Paris 13ème - Restaurant - Paris 13ème - Les mieux notés
# General match found: {'name': 'Les mieux notés', 'location': 'Paris 13ème', 'cuisine': 'Les mieux notés'}
# Processing row: Restaurant TheFork Festival proche Paris 13ème - Restaurant - Paris 13ème - TheFork Festival
# General match found: {'name': 'TheFork Festival', 'location': 'Paris 13ème', 'cuisine': 'TheFork Festival'}
# Processing row: Restaurant Black Friday proche Paris 13ème - Restaurant - Paris 13ème - Black Friday
# General match found: {'name': 'Black Friday', 'location': 'Paris 13ème', 'cuisine': 'Black Friday'}
# Processing row: Restaurant Les nouveaux restaurants sur TheFork proche Paris 13ème - Restaurant - Paris 13ème - Les nouveaux restaurants sur TheFork
# General match found: {'name': 'Les nouveaux restaurants sur TheFork', 'location': 'Paris 13ème', 'cuisine': 'Les nouveaux restaurants sur TheFork'}
# Processing row: Restaurant Saint-Valentin proche Paris 13ème - Restaurant - Paris 13ème - Saint-Valentin
# General match found: {'name': 'Saint-Valentin', 'location': 'Paris 13ème', 'cuisine': 'Saint-Valentin'}
# Processing row: Restaurant Nouvel An proche Paris 13ème - Restaurant - Paris 13ème - Nouvel An
# General match found: {'name': 'Nouvel An', 'location': 'Paris 13ème', 'cuisine': 'Nouvel An'}
# Processing row: Restaurant Noël proche Paris 13ème - Restaurant - Paris 13ème - Noël
# General match found: {'name': 'Noël', 'location': 'Paris 13ème', 'cuisine': 'Noël'}
# Processing row: Restaurant Petit Prix proche Paris 13ème - Restaurant - Paris 13ème - Petit Prix
# General match found: {'name': 'Petit Prix', 'location': 'Paris 13ème', 'cuisine': 'Petit Prix'}
# Processing row: Restaurant Diffuse les matchs de football proche Paris 13ème - Restaurant - Paris 13ème - Diffuse les matchs de football
# General match found: {'name': 'Diffuse les matchs de football', 'location': 'Paris 13ème', 'cuisine': 'Diffuse les matchs de football'}
# Processing row: Restaurant Privatisable proche Paris 13ème - Restaurant - Paris 13ème - Privatisable
# General match found: {'name': 'Privatisable', 'location': 'Paris 13ème', 'cuisine': 'Privatisable'}
# Processing row: Restaurant Ouverts le dimanche proche Paris 13ème - Restaurant - Paris 13ème - Ouverts le dimanche
# General match found: {'name': 'Ouverts le dimanche', 'location': 'Paris 13ème', 'cuisine': 'Ouverts le dimanche'}
# Processing row: Restaurant Accès personnes à mobilité réduite proche Paris 13ème - Restaurant - Paris 13ème - Accès personnes à mobilité réduite
# General match found: {'name': 'Accès personnes à mobilité réduite', 'location': 'Paris 13ème', 'cuisine': 'Accès personnes à mobilité réduite'}
# Processing row: Restaurant Belle cave à vins proche Paris 13ème - Restaurant - Paris 13ème - Belle cave à vins
# General match found: {'name': 'Belle cave à vins', 'location': 'Paris 13ème', 'cuisine': 'Belle cave à vins'}
# Processing row: Restaurant Entre amis proche Paris 13ème - Restaurant - Paris 13ème - Entre amis
# General match found: {'name': 'Entre amis', 'location': 'Paris 13ème', 'cuisine': 'Entre amis'}
# Processing row: Restaurant Terrasse proche Paris 13ème - Restaurant - Paris 13ème - Terrasse
# General match found: {'name': 'Terrasse', 'location': 'Paris 13ème', 'cuisine': 'Terrasse'}
# Processing row: Restaurant Déjeuner proche Paris 13ème - Restaurant - Paris 13ème - Déjeuner
# General match found: {'name': 'Déjeuner', 'location': 'Paris 13ème', 'cuisine': 'Déjeuner'}
# Processing row: Restaurant En famille proche Paris 13ème - Restaurant - Paris 13ème - En famille
# General match found: {'name': 'En famille', 'location': 'Paris 13ème', 'cuisine': 'En famille'}
# Processing row: Restaurant Traditionnel proche Paris 13ème - Restaurant - Paris 13ème - Traditionnel
# General match found: {'name': 'Traditionnel', 'location': 'Paris 13ème', 'cuisine': 'Traditionnel'}
# Processing row: Restaurant Romantique proche Paris 13ème - Restaurant - Paris 13ème - Romantique
# General match found: {'name': 'Romantique', 'location': 'Paris 13ème', 'cuisine': 'Romantique'}
# Processing row: Restaurant Cosy proche Paris 13ème - Restaurant - Paris 13ème - Cosy
# General match found: {'name': 'Cosy', 'location': 'Paris 13ème', 'cuisine': 'Cosy'}
# Processing row: Restaurant Enfants bienvenus ! proche Paris 13ème - Restaurant - Paris 13ème - Enfants bienvenus !
# General match found: {'name': 'Enfants bienvenus !', 'location': 'Paris 13ème', 'cuisine': 'Enfants bienvenus !'}
# Processing row: Restaurant Cuisine contemporaine proche Paris 13ème - Restaurant - Paris 13ème - Cuisine contemporaine
# General match found: {'name': 'Cuisine contemporaine', 'location': 'Paris 13ème', 'cuisine': 'Cuisine contemporaine'}
# Processing row: Restaurant Branché proche Paris 13ème - Restaurant - Paris 13ème - Branché
# General match found: {'name': 'Branché', 'location': 'Paris 13ème', 'cuisine': 'Branché'}
# Processing row: Restaurant Brunch proche Paris 13ème - Restaurant - Paris 13ème - Brunch
# General match found: {'name': 'Brunch', 'location': 'Paris 13ème', 'cuisine': 'Brunch'}
# Processing row: Restaurant Bistrot proche Paris 13ème - Restaurant - Paris 13ème - Bistrot
# General match found: {'name': 'Bistrot', 'location': 'Paris 13ème', 'cuisine': 'Bistrot'}
# Processing row: Restaurant Spécial groupe proche Paris 13ème - Restaurant - Paris 13ème - Spécial groupe
# General match found: {'name': 'Spécial groupe', 'location': 'Paris 13ème', 'cuisine': 'Spécial groupe'}
# Processing row: Restaurant Bistronomique proche Paris 13ème - Restaurant - Paris 13ème - Bistronomique
# General match found: {'name': 'Bistronomique', 'location': 'Paris 13ème', 'cuisine': 'Bistronomique'}
# Processing row: Restaurant Brasserie proche Paris 13ème - Restaurant - Paris 13ème - Brasserie
# General match found: {'name': 'Brasserie', 'location': 'Paris 13ème', 'cuisine': 'Brasserie'}
# Processing row: Restaurant Gastronomique proche Paris 13ème - Restaurant - Paris 13ème - Gastronomique
# General match found: {'name': 'Gastronomique', 'location': 'Paris 13ème', 'cuisine': 'Gastronomique'}
# Processing row: Restaurant Repas d'affaires proche Paris 13ème - Restaurant - Paris 13ème - Repas d'affaires
# General match found: {'name': "Repas d'affaires", 'location': 'Paris 13ème', 'cuisine': "Repas d'affaires"}
# Processing row: Restaurant Anniversaire proche Paris 13ème - Restaurant - Paris 13ème - Anniversaire
# General match found: {'name': 'Anniversaire', 'location': 'Paris 13ème', 'cuisine': 'Anniversaire'}
# Processing row: Restaurant Au bord de l'eau proche Paris 13ème - Restaurant - Paris 13ème - Au bord de l'eau
# General match found: {'name': "Au bord de l'eau", 'location': 'Paris 13ème', 'cuisine': "Au bord de l'eau"}
# Processing row: Restaurant Sur une péniche proche Paris 13ème - Restaurant - Paris 13ème - Sur une péniche
# General match found: {'name': 'Sur une péniche', 'location': 'Paris 13ème', 'cuisine': 'Sur une péniche'}
# Processing row: Restaurant Winstub proche Paris 13ème - Restaurant - Paris 13ème - Winstub
# General match found: {'name': 'Winstub', 'location': 'Paris 13ème', 'cuisine': 'Winstub'}
# Processing row: Restaurant Asiatique proche Paris 13ème - Restaurant - Paris 13ème - Asiatique
# General match found: {'name': 'Asiatique', 'location': 'Paris 13ème', 'cuisine': 'Asiatique'}
# Processing row: Restaurant Français proche Paris 13ème - Restaurant - Paris 13ème - Français
# General match found: {'name': 'Français', 'location': 'Paris 13ème', 'cuisine': 'Français'}
# Processing row: Restaurant Italien proche Paris 13ème - Restaurant - Paris 13ème - Italien
# General match found: {'name': 'Italien', 'location': 'Paris 13ème', 'cuisine': 'Italien'}
# Processing row: Restaurant Vietnamien proche Paris 13ème - Restaurant - Paris 13ème - Vietnamien
# General match found: {'name': 'Vietnamien', 'location': 'Paris 13ème', 'cuisine': 'Vietnamien'}
# Processing row: Restaurant Oriental proche Paris 13ème - Restaurant - Paris 13ème - Oriental
# General match found: {'name': 'Oriental', 'location': 'Paris 13ème', 'cuisine': 'Oriental'}
# Processing row: Restaurant Cuisine du monde proche Paris 13ème - Restaurant - Paris 13ème - Cuisine du monde
# General match found: {'name': 'Cuisine du monde', 'location': 'Paris 13ème', 'cuisine': 'Cuisine du monde'}
# Processing row: Restaurant Thaïlandais proche Paris 13ème - Restaurant - Paris 13ème - Thaïlandais
# General match found: {'name': 'Thaïlandais', 'location': 'Paris 13ème', 'cuisine': 'Thaïlandais'}
# Processing row: Restaurant Japonais proche Paris 13ème - Restaurant - Paris 13ème - Japonais
# General match found: {'name': 'Japonais', 'location': 'Paris 13ème', 'cuisine': 'Japonais'}
# Processing row: Restaurant Chinois proche Paris 13ème - Restaurant - Paris 13ème - Chinois
# General match found: {'name': 'Chinois', 'location': 'Paris 13ème', 'cuisine': 'Chinois'}
# Processing row: Restaurant Indien proche Paris 13ème - Restaurant - Paris 13ème - Indien
# General match found: {'name': 'Indien', 'location': 'Paris 13ème', 'cuisine': 'Indien'}
# Processing row: Restaurant Coréen proche Paris 13ème - Restaurant - Paris 13ème - Coréen
# General match found: {'name': 'Coréen', 'location': 'Paris 13ème', 'cuisine': 'Coréen'}
# Processing row: Restaurant Africain proche Paris 13ème - Restaurant - Paris 13ème - Africain
# General match found: {'name': 'Africain', 'location': 'Paris 13ème', 'cuisine': 'Africain'}
# Processing row: Restaurant Fusion proche Paris 13ème - Restaurant - Paris 13ème - Fusion
# General match found: {'name': 'Fusion', 'location': 'Paris 13ème', 'cuisine': 'Fusion'}
# Processing row: Restaurant Latino proche Paris 13ème - Restaurant - Paris 13ème - Latino
# General match found: {'name': 'Latino', 'location': 'Paris 13ème', 'cuisine': 'Latino'}
# Processing row: Restaurant Méditérranéen proche Paris 13ème - Restaurant - Paris 13ème - Méditérranéen
# General match found: {'name': 'Méditérranéen', 'location': 'Paris 13ème', 'cuisine': 'Méditérranéen'}
# Processing row: Restaurant Libanais proche Paris 13ème - Restaurant - Paris 13ème - Libanais
# General match found: {'name': 'Libanais', 'location': 'Paris 13ème', 'cuisine': 'Libanais'}
# Processing row: Restaurant Crêperie proche Paris 13ème - Restaurant - Paris 13ème - Crêperie
# General match found: {'name': 'Crêperie', 'location': 'Paris 13ème', 'cuisine': 'Crêperie'}
# Processing row: Restaurant Algérien proche Paris 13ème - Restaurant - Paris 13ème - Algérien
# General match found: {'name': 'Algérien', 'location': 'Paris 13ème', 'cuisine': 'Algérien'}
# Processing row: Restaurant Tunisien proche Paris 13ème - Restaurant - Paris 13ème - Tunisien
# General match found: {'name': 'Tunisien', 'location': 'Paris 13ème', 'cuisine': 'Tunisien'}
# Processing row: Restaurant YUMS x2 proche Paris 13ème - Restaurant - Paris 13ème - YUMS x2
# General match found: {'name': 'YUMS x2', 'location': 'Paris 13ème', 'cuisine': 'YUMS x2'}
# Processing row: Restaurant Acceptant mes Yums proche Paris 13ème - Restaurant - Paris 13ème - Acceptant mes Yums
# General match found: {'name': 'Acceptant mes Yums', 'location': 'Paris 13ème', 'cuisine': 'Acceptant mes Yums'}
# Processing row: Restaurant INSIDER proche Paris 13ème - Restaurant - Paris 13ème - INSIDER
# General match found: {'name': 'INSIDER', 'location': 'Paris 13ème', 'cuisine': 'INSIDER'}
# Processing row: Kenzy - 15 Rue Jeanne Chauvin, 75013, Paris - Oriental
# Specific match found: {'name': 'Kenzy', 'address': '15 Rue Jeanne Chauvin', 'postal_code': '75013', 'city': 'Paris', 'cuisine': 'Oriental'}
# Processing row: Le WokCafe Paris - 33 Rue Pascal, 75013, Paris - Asiatique
# Specific match found: {'name': 'Le WokCafe Paris', 'address': '33 Rue Pascal', 'postal_code': '75013', 'city': 'Paris', 'cuisine': 'Asiatique'}
# Processing row: Allotrope - 38 Rue des cinq Diamants, 75013, Paris - Italien
# Specific match found: {'name': 'Allotrope', 'address': '38 Rue des cinq Diamants', 'postal_code': '75013', 'city': 'Paris', 'cuisine': 'Italien'}
# Processing row: Florina - 47 Boulevard de Port-Royal, 75013, Paris-13E-Arrondissement - Français
# No match found for this row.
# Processing row: Station Krishna - 16, rue du Père Guérin, 75013, Paris - Indien
# Specific match found: {'name': 'Station Krishna', 'address': '16, rue du Père Guérin', 'postal_code': '75013', 'city': 'Paris', 'cuisine': 'Indien'}
# Processing row: SAI Restaurant Indien - 9 Rue Michel Peter, 75013, Paris - Indien
# Specific match found: {'name': 'SAI Restaurant Indien', 'address': '9 Rue Michel Peter', 'postal_code': '75013', 'city': 'Paris', 'cuisine': 'Indien'}
# Processing row: Sushi Osaka - 37 Bd Auguste Blanqui, 75013, Paris - Japonais
# Specific match found: {'name': 'Sushi Osaka', 'address': '37 Bd Auguste Blanqui', 'postal_code': '75013', 'city': 'Paris', 'cuisine': 'Japonais'}
# Processing row: Nieli - 17/19, rue Louise Weiss, 75013, Paris - Pizzeria
# Specific match found: {'name': 'Nieli', 'address': '17/19, rue Louise Weiss', 'postal_code': '75013', 'city': 'Paris', 'cuisine': 'Pizzeria'}
# Processing row: Cayo Coffee Roasters - 9 Rue du Chevaleret, 75013, Paris - Cuisine du monde
# Specific match found: {'name': 'Cayo Coffee Roasters', 'address': '9 Rue du Chevaleret', 'postal_code': '75013', 'city': 'Paris', 'cuisine': 'Cuisine du monde'}
# Processing row: Pâtes Thaï - Place d'italie - 6 Rue Primatice, 75013, Paris - Thaïlandais
# Specific match found: {'name': "Pâtes Thaï - Place d'italie", 'address': '6 Rue Primatice', 'postal_code': '75013', 'city': 'Paris', 'cuisine': 'Thaïlandais'}
# Processing row: O Mexico - 20, rue du père Guérin, 75013, Paris - Mexicain
# Specific match found: {'name': 'O Mexico', 'address': '20, rue du père Guérin', 'postal_code': '75013', 'city': 'Paris', 'cuisine': 'Mexicain'}
# Processing row: Restaurant Elephant - 137 Bd de l'Hôpital, 75013, Paris - Thaïlandais
# Specific match found: {'name': 'Restaurant Elephant', 'address': "137 Bd de l'Hôpital", 'postal_code': '75013', 'city': 'Paris', 'cuisine': 'Thaïlandais'}
# Processing row: Le Royal Fondue - 98 Av. de Choisy, 75013, Paris - Chinois
# Specific match found: {'name': 'Le Royal Fondue', 'address': '98 Av. de Choisy', 'postal_code': '75013', 'city': 'Paris', 'cuisine': 'Chinois'}
# Processing row: Auberge Etchegorry - 41, rue Croulebarbe, 75013, Paris - Sud-Ouest
# Specific match found: {'name': 'Auberge Etchegorry', 'address': '41, rue Croulebarbe', 'postal_code': '75013', 'city': 'Paris', 'cuisine': 'Sud-Ouest'}
# Processing row: EL cucho - 105 Rue de Tolbiac, 75013, Paris - Colombien
# Specific match found: {'name': 'EL cucho', 'address': '105 Rue de Tolbiac', 'postal_code': '75013', 'city': 'Paris', 'cuisine': 'Colombien'}
# Processing row: Pho Indochine - 31 Rue Nationale, 75013, Paris - Vietnamien
# Specific match found: {'name': 'Pho Indochine', 'address': '31 Rue Nationale', 'postal_code': '75013', 'city': 'Paris', 'cuisine': 'Vietnamien'}
# Processing row: Saveurs d'Himalaya - 22 Rue Boussingault, 75013, Paris - Indien
# Specific match found: {'name': "Saveurs d'Himalaya", 'address': '22 Rue Boussingault', 'postal_code': '75013', 'city': 'Paris', 'cuisine': 'Indien'}
# Processing row: Sangeet - 64 Rue de la Glacière, 75013, Paris - Indien
# Specific match found: {'name': 'Sangeet', 'address': '64 Rue de la Glacière', 'postal_code': '75013', 'city': 'Paris', 'cuisine': 'Indien'}
# Processing row: La Ménagerie - 90 Bd de l'Hôpital, 75013, Paris - Français
# Specific match found: {'name': 'La Ménagerie', 'address': "90 Bd de l'Hôpital", 'postal_code': '75013', 'city': 'Paris', 'cuisine': 'Français'}
# Processing row: Yuman - 70 Rue du Chevaleret, 75013, Paris - Européen
# Specific match found: {'name': 'Yuman', 'address': '70 Rue du Chevaleret', 'postal_code': '75013', 'city': 'Paris', 'cuisine': 'Européen'}
# Processing row: N+1 - 151 Rue du Chevaleret, 75013, Paris - Français
# Specific match found: {'name': 'N+1', 'address': '151 Rue du Chevaleret', 'postal_code': '75013', 'city': 'Paris', 'cuisine': 'Français'}
# Processing row: Le Phénix 御华园 - 29 Rue de Campo-Formio, 75013, Paris - Chinois
# Specific match found: {'name': 'Le Phénix 御华园', 'address': '29 Rue de Campo-Formio', 'postal_code': '75013', 'city': 'Paris', 'cuisine': 'Chinois'}
# Processing row: L'atelier Saisonnier Paris 13 - 55 Rue de Tolbiac, 75013, Paris - Français
# Specific match found: {'name': "L'atelier Saisonnier Paris 13", 'address': '55 Rue de Tolbiac', 'postal_code': '75013', 'city': 'Paris', 'cuisine': 'Français'}
# Processing row: Ti Amo - Place d'Italie - 55 Rue de Tolbiac, 75013, Paris - Italian
# Specific match found: {'name': "Ti Amo - Place d'Italie", 'address': '55 Rue de Tolbiac', 'postal_code': '75013', 'city': 'Paris', 'cuisine': 'Italian'}
# Processing row: Brasserie L'Avenue - 27 Boulevard Auguste Blanqui, 75013, Paris - French
# Specific match found: {'name': "Brasserie L'Avenue", 'address': '27 Boulevard Auguste Blanqui', 'postal_code': '75013', 'city': 'Paris', 'cuisine': 'French'}
# Extracted Features DataFrame:
#        Name Address Postal Code   City District Cuisine Type
# 0    Poulet    None        None  13ème    13ème       Poulet
# 1     Pizza    None        None  13ème    13ème        Pizza
# 2  Pad Thai    None        None  13ème    13ème     Pad Thai
# 3     Sushi    None        None  13ème    13ème        Sushi
# 4  Couscous    None        None  13ème    13ème     Couscous
# Processed data saved to C:/Users/Bhargav/travel chat/extracted_features.csv
#        Name Address Postal Code   City District Cuisine Type
# 0    Poulet    None        None  13ème    13ème       Poulet
# 1     Pizza    None        None  13ème    13ème        Pizza
# 2  Pad Thai    None        None  13ème    13ème     Pad Thai
# 3     Sushi    None        None  13ème    13ème        Sushi
# 4  Couscous    None        None  13ème    13ème     Couscous
